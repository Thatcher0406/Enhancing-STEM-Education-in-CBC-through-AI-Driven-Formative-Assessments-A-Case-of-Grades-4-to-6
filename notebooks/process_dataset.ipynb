# %%
# Step 2: Data Processing – Clean and Prepare for LLaMA-2 Fine-Tuning

import pandas as pd
import json
import os

# %%
# Load the CBC dataset created in Step 1
input_path = "../backend/data/cbc_questions.csv"
df = pd.read_csv(input_path)

print("✅ Loaded dataset with", len(df), "records")
df.head()
# Out:
# ✅ Loaded dataset with 13 records
#        subject  grade cbc_code  bloom_level  \
# 0  Mathematics      4   M4.1.1            1
# 1  Mathematics      4   M4.2.3            2
# 2  Mathematics      5   M5.3.2            3
# 3  Mathematics      6   M6.4.1            4
# 4      Science      4   S4.1.1            1
#
#                                             question  \
# 0                                     What is 5 + 7?
# 1                     Which shape has 4 equal sides?
# 2  A triangle has sides of 3 cm, 4 cm, and 5 cm. ...
# 3  If the radius of a circle is 7 cm, find its ar...
# 4               Which organ helps humans to breathe?
#
#                                              options        answer
# 0                           ['10', '11', '12', '13']            12
# 1      ['Rectangle', 'Square', 'Triangle', 'Circle']        Square
# 2  ['Equilateral', 'Isosceles', 'Right-angled', '...  Right-angled
# 3       ['144 cm²', '154 cm²', '132 cm²', '160 cm²']       154 cm²
# 4              ['Lungs', 'Heart', 'Brain', 'Kidney']         Lungs

# %%
# Clean nulls or empty fields
df = df.dropna(subset=["subject", "grade", "question", "answer"])

# Standardize text casing (for consistency)
df["subject"] = df["subject"].str.strip().str.title()
df["cbc_code"] = df["cbc_code"].str.upper()

# Ensure Bloom’s levels are integers (1–6)
df["bloom_level"] = df["bloom_level"].astype(int)
df = df[df["bloom_level"].between(1, 6)]

print("✅ Cleaned and normalized data")
df.sample(5)
# Out:
# ✅ Cleaned and normalized data
#         subject  grade cbc_code  bloom_level  \
# 4       Science      4   S4.1.1            1
# 7       English      4   E4.1.1            1
# 0   Mathematics      4   M4.1.1            1
# 6       Science      6   S6.3.2            3
# 12      English      6   E6.3.4            5
#
#                                              question  \
# 4                Which organ helps humans to breathe?
# 7          Choose the correct plural form of 'child'.
# 0                                      What is 5 + 7?
# 6   Which process describes how plants make their ...
# 12  Choose the sentence that uses the correct form...
#
#                                               options  \
# 4               ['Lungs', 'Heart', 'Brain', 'Kidney']
# 7          ['childs', 'childes', 'children', 'child']
# 0                            ['10', '11', '12', '13']
# 6   ['Transpiration', 'Photosynthesis', 'Respirati...
# 12  ['They was going to school.', 'They were going...
#
#                         answer
# 4                        Lungs
# 7                     children
# 0                           12
# 6               Photosynthesis
# 12  They were going to school.

# %%
# Map Bloom’s levels to human-readable labels
bloom_map = {
    1: "Remember",
    2: "Understand",
    3: "Apply",
    4: "Analyze",
    5: "Evaluate",
    6: "Create"
}

df["bloom_category"] = df["bloom_level"].map(bloom_map)
print("✅ Added Bloom’s taxonomy categories")
df[["subject", "grade", "cbc_code", "bloom_category"]].head()
# Out:
# ✅ Added Bloom’s taxonomy categories
#        subject  grade cbc_code bloom_category
# 0  Mathematics      4   M4.1.1       Remember
# 1  Mathematics      4   M4.2.3     Understand
# 2  Mathematics      5   M5.3.2          Apply
# 3  Mathematics      6   M6.4.1        Analyze
# 4      Science      4   S4.1.1       Remember

# %%
# Function to build prompt-completion pairs
def make_prompt(row):
    return (
        f"Generate a CBC-aligned question for Grade {row['grade']} {row['subject']} "
        f"based on code {row['cbc_code']} at the '{row['bloom_category']}' Bloom level."
    )

def make_completion(row):
    opts = ", ".join(row['options'].split(',')) if isinstance(row['options'], str) else ", ".join(row['options'])
    return (
        f"Question: {row['question']} Options: {opts}. Answer: {row['answer']}"
    )

# Apply functions
df["prompt"] = df.apply(make_prompt, axis=1)
df["completion"] = df.apply(make_completion, axis=1)

print("✅ Created prompt–completion pairs")
df[["prompt", "completion"]].head(3)
# Out:
# ✅ Created prompt–completion pairs
#                                               prompt  \
# 0  Generate a CBC-aligned question for Grade 4 Ma...
# 1  Generate a CBC-aligned question for Grade 4 Ma...
# 2  Generate a CBC-aligned question for Grade 5 Ma...
#
#                                           completion
# 0  Question: What is 5 + 7? Options: ['10',  '11'...
# 1  Question: Which shape has 4 equal sides? Optio...
# 2  Question: A triangle has sides of 3 cm, 4 cm, ...

# %%
output_path = "../backend/data/cbc_finetune_dataset.jsonl"

# Convert to JSON Lines format
with open(output_path, "w", encoding="utf-8") as f:
    for _, row in df.iterrows():
        record = {"prompt": row["prompt"], "completion": row["completion"]}
        f.write(json.dumps(record, ensure_ascii=False) + "\n")

print(f"✅ Fine-tuning dataset saved to {output_path}")
# Out:
# ✅ Fine-tuning dataset saved to ../backend/data/cbc_finetune_dataset.jsonl

# %%
print("\n--- Summary ---")
print(df.groupby("subject")["grade"].count())
print("\nBloom’s Level Distribution:")
print(df["bloom_category"].value_counts())

df.head()
# Out:
# --- Summary ---
# subject
# English        6
# Mathematics    4
# Science        3
# Name: grade, dtype: int64
#
# Bloom’s Level Distribution:
# bloom_category
# Understand    4
# Remember      3
# Apply         3
# Analyze       2
# Evaluate      1
# Name: count, dtype: int64
#        subject  grade cbc_code  bloom_level  \
# 0  Mathematics      4   M4.1.1            1
# 1  Mathematics      4   M4.2.3            2
# 2  Mathematics      5   M5.3.2            3
# 3  Mathematics      6   M6.4.1            4
# 4      Science      4   S4.1.1            1
#
#                                             question  \
# 0                                     What is 5 + 7?
# 1                     Which shape has 4 equal sides?
# 2  A triangle has sides of 3 cm, 4 cm, and 5 cm. ...
# 3  If the radius of a circle is 7 cm, find its ar...
# 4               Which organ helps humans to breathe?
#
#                                              options        answer  \
# 0                           ['10', '11', '12', '13']            12
# 1      ['Rectangle', 'Square', 'Triangle', 'Circle']        Square
# 2  ['Equilateral', 'Isosceles', 'Right-angled', '...  Right-angled
# 3       ['144 cm²', '154 cm²', '132 cm²', '160 cm²']       154 cm²
# 4              ['Lungs', 'Heart', 'Brain', 'Kidney']         Lungs
#
#   bloom_category                                             prompt  \
# 0       Remember  Generate a CBC-aligned question for Grade 4 Ma...
# 1     Understand  Generate a CBC-aligned question for Grade 4 Ma...
# 2          Apply  Generate a CBC-aligned question for Grade 5 Ma...
# 3        Analyze  Generate a CBC-aligned question for Grade 6 Ma...
# 4       Remember  Generate a CBC-aligned question for Grade 4 Sc...
#
#                                           completion
# 0  Question: What is 5 + 7? Options: ['10',  '11'...
# 1  Question: Which shape has 4 equal sides? Optio...
# 2  Question: A triangle has sides of 3 cm, 4 cm, ...
# 3  Question: If the radius of a circle is 7 cm, f...
# 4  Question: Which organ helps humans to breathe?...
