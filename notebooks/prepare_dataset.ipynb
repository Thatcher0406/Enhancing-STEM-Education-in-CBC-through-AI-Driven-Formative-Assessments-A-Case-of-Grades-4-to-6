# %%
# Step 1: Data Acquisition – Create Seed CBC Dataset

import pandas as pd
import os

# %%
# Ensure the data folder exists inside backend/
os.makedirs("../backend/data", exist_ok=True)

# %%
# --- CBC Seed Data (Grade 4–6: Mathematics, Science, English) ---
data = [
    # === Grade 4 Mathematics ===
    {"subject": "Mathematics", "grade": 4, "cbc_code": "M4.1.1", "bloom_level": 1,
     "question": "What is 5 + 7?", "options": ["10", "11", "12", "13"], "answer": "12"},
    
    {"subject": "Mathematics", "grade": 4, "cbc_code": "M4.2.3", "bloom_level": 2,
     "question": "Which shape has 4 equal sides?", "options": ["Rectangle", "Square", "Triangle", "Circle"], "answer": "Square"},

    # === Grade 5 Mathematics ===
    {"subject": "Mathematics", "grade": 5, "cbc_code": "M5.3.2", "bloom_level": 3,
     "question": "A triangle has sides of 3 cm, 4 cm, and 5 cm. What type of triangle is it?",
     "options": ["Equilateral", "Isosceles", "Right-angled", "Scalene"], "answer": "Right-angled"},

    # === Grade 6 Mathematics ===
    {"subject": "Mathematics", "grade": 6, "cbc_code": "M6.4.1", "bloom_level": 4,
     "question": "If the radius of a circle is 7 cm, find its area. (Use π = 22/7)",
     "options": ["144 cm²", "154 cm²", "132 cm²", "160 cm²"], "answer": "154 cm²"},

    # === Grade 4 Science ===
    {"subject": "Science", "grade": 4, "cbc_code": "S4.1.1", "bloom_level": 1,
     "question": "Which organ helps humans to breathe?", "options": ["Lungs", "Heart", "Brain", "Kidney"], "answer": "Lungs"},

    # === Grade 5 Science ===
    {"subject": "Science", "grade": 5, "cbc_code": "S5.2.3", "bloom_level": 2,
     "question": "Which organ pumps blood in the human body?",
     "options": ["Lungs", "Heart", "Liver", "Kidney"], "answer": "Heart"},

    # === Grade 6 Science ===
    {"subject": "Science", "grade": 6, "cbc_code": "S6.3.2", "bloom_level": 3,
     "question": "Which process describes how plants make their food?",
     "options": ["Transpiration", "Photosynthesis", "Respiration", "Fertilization"], "answer": "Photosynthesis"},

    # === Grade 4 English ===
    {"subject": "English", "grade": 4, "cbc_code": "E4.1.1", "bloom_level": 1,
     "question": "Choose the correct plural form of 'child'.",
     "options": ["childs", "childes", "children", "child"], "answer": "children"},

    {"subject": "English", "grade": 4, "cbc_code": "E4.1.3", "bloom_level": 2,
     "question": "Which of the following is a noun?",
     "options": ["run", "happy", "school", "quickly"], "answer": "school"},

    # === Grade 5 English ===
    {"subject": "English", "grade": 5, "cbc_code": "E5.2.2", "bloom_level": 3,
     "question": "Select the sentence with correct punctuation.",
     "options": [
         "My brother likes football he plays every day.",
         "My brother likes football; he plays every day.",
         "My brother likes football he, plays every day.",
         "My brother likes football he plays, every day."
     ],
     "answer": "My brother likes football; he plays every day."},

    {"subject": "English", "grade": 5, "cbc_code": "E5.2.4", "bloom_level": 2,
     "question": "Which word is the opposite of 'brave'?",
     "options": ["courageous", "fearful", "strong", "bold"], "answer": "fearful"},

    # === Grade 6 English ===
    {"subject": "English", "grade": 6, "cbc_code": "E6.3.1", "bloom_level": 4,
     "question": "Read the sentence: 'She arrived early because she wanted to help.' What is the conjunction in the sentence?",
     "options": ["She", "because", "early", "help"], "answer": "because"},

    {"subject": "English", "grade": 6, "cbc_code": "E6.3.4", "bloom_level": 5,
     "question": "Choose the sentence that uses the correct form of the verb 'to be'.",
     "options": [
         "They was going to school.",
         "They were going to school.",
         "They is going to school.",
         "They be going to school."
     ],
     "answer": "They were going to school."}
]

# %%
# Create DataFrame
df = pd.DataFrame(data)

# %%
# Save to CSV
csv_path = "../backend/data/cbc_questions.csv"
df.to_csv(csv_path, index=False)

# %%
print(f"✅ CBC seed dataset created and saved to {csv_path}")
df.head()
# Out:
# ✅ CBC seed dataset created and saved to ../backend/data/cbc_questions.csv
#        subject  grade cbc_code  bloom_level  \
# 0  Mathematics      4   M4.1.1            1
# 1  Mathematics      4   M4.2.3            2
# 2  Mathematics      5   M5.3.2            3
# 3  Mathematics      6   M6.4.1            4
# 4      Science      4   S4.1.1            1
#
#                                             question  \
# 0                                     What is 5 + 7?
# 1                     Which shape has 4 equal sides?
# 2  A triangle has sides of 3 cm, 4 cm, and 5 cm. ...
# 3  If the radius of a circle is 7 cm, find its ar...
# 4               Which organ helps humans to breathe?
#
#                                            options        answer
# 0                                 [10, 11, 12, 13]            12
# 1            [Rectangle, Square, Triangle, Circle]        Square
# 2  [Equilateral, Isosceles, Right-angled, Scalene]  Right-angled
# ...
